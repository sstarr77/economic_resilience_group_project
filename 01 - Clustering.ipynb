# %% [markdown]
# # 01 - Clustering Notebook
# The intent of this notebook is to cluster our data to find meaningful relationships within the data. Within this notebook, we will be scaling the data we would like to cluster, then perform a FeatureUnion to bring in the remaining data, before running it through both a DBScan and KMeans model. At the end of the notebook, we analyze our findings by cluster.

# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# plt.style.use('ggplot') 
# %matplotlib inline

# sklearn imports
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score

# %%
np.random.seed(40)

# %%
df_2018 = pd.read_csv('./source_data/economies_2018.csv', index_col =0)
df_2021 = pd.read_csv('./source_data/economies_2021.csv', index_col =0)

df_2018.head()
# Out:
#             Total Nonfarm  Manufacturing  Trade, Transportation, and Utils  \
# Alabama          2046.258        266.992                           383.467
# Alaska            327.658         12.500                            64.408
# Arizona          2857.717        171.450                           534.525
# Arkansas         1267.492        160.800                           253.408
# California      17172.225       1323.550                          3045.983
#
#             Information  Financial Activities  \
# Alabama          21.092                96.258
# Alaska            5.608                11.767
# Arizona          47.558               220.008
# Arkansas         12.433                61.058
# California      542.850               837.875
#
#             Professional & Business Services  Education & Health Services  \
# Alabama                              244.242                      245.167
# Alaska                                27.358                       50.442
# Arizona                              434.033                      445.417
# Arkansas                             145.425                      191.575
# California                          2670.217                     2722.283
#
#             Leisure & Hospitality  Other Services  Government  ...  \
# Alabama                   205.933          97.117     386.792  ...
# Alaska                     35.650          11.058      80.375  ...
# Arizona                   325.975          92.442     415.858  ...
# Arkansas                  118.267          55.650     212.108  ...
# California               1993.142         571.667    2581.483  ...
#
#             pct_Manufacturing  pct_Trade, Transportation, and Utils  \
# Alabama                0.1305                                0.1874
# Alaska                 0.0381                                0.1966
# Arizona                0.0600                                0.1870
# Arkansas               0.1269                                0.1999
# California             0.0771                                0.1774
#
#             pct_Information  pct_Financial Activities  \
# Alabama              0.0103                    0.0470
# Alaska               0.0171                    0.0359
# Arizona              0.0166                    0.0770
# Arkansas             0.0098                    0.0482
# California           0.0316                    0.0488
#
#             pct_Professional & Business Services  \
# Alabama                                   0.1194
# Alaska                                    0.0835
# Arizona                                   0.1519
# Arkansas                                  0.1147
# California                                0.1555
#
#             pct_Education & Health Services  pct_Leisure & Hospitality  \
# Alabama                              0.1198                     0.1006
# Alaska                               0.1539                     0.1088
# Arizona                              0.1559                     0.1141
# Arkansas                             0.1511                     0.0933
# California                           0.1585                     0.1161
#
#             pct_Other Services  pct_Government  \
# Alabama                 0.0475          0.1890
# Alaska                  0.0337          0.2453
# Arizona                 0.0323          0.1455
# Arkansas                0.0439          0.1673
# California              0.0333          0.1503
#
#             pct_Mining, Logging and Construction
# Alabama                                   0.0485
# Alaska                                    0.0870
# Arizona                                   0.0596
# Arkansas                                  0.0448
# California                                0.0514
#
# [5 rows x 21 columns]

# %%
# Check for null values in dataframes
print(df_2021.isnull().sum())
print(df_2018.isnull().sum())
# Out:
# Total Nonfarm                           0
# Manufacturing                           0
# Trade, Transportation, and Utils        0
# Information                             0
# Financial Activities                    0
# Professional & Business Services        0
# Education & Health Services             0
# Leisure & Hospitality                   0
# Other Services                          0
# Government                              0
# Mining, Logging and Construction        0
# pct_Manufacturing                       0
# pct_Trade, Transportation, and Utils    0
# pct_Information                         0
# pct_Financial Activities                0
# pct_Professional & Business Services    0
# pct_Education & Health Services         0
# pct_Leisure & Hospitality               0
# pct_Other Services                      0
# pct_Government                          0
# pct_Mining, Logging and Construction    0
# dtype: int64
# Total Nonfarm                           0
# Manufacturing                           0
# Trade, Transportation, and Utils        0
# Information                             0
# Financial Activities                    0
# Professional & Business Services        0
# Education & Health Services             0
# Leisure & Hospitality                   0
# Other Services                          0
# Government                              0
# Mining, Logging and Construction        0
# pct_Manufacturing                       0
# pct_Trade, Transportation, and Utils    0
# pct_Information                         0
# pct_Financial Activities                0
# pct_Professional & Business Services    0
# pct_Education & Health Services         0
# pct_Leisure & Hospitality               0
# pct_Other Services                      0
# pct_Government                          0
# pct_Mining, Logging and Construction    0
# dtype: int64

# %% [markdown]
# #### Scaling & FeatureUnion within Pipelines

# %%
target_columns = df_2018.drop(columns=df_2018.columns[1:11]).columns
target_columns
# Out:
# Index(['Total Nonfarm', 'pct_Manufacturing',
#        'pct_Trade, Transportation, and Utils', 'pct_Information',
#        'pct_Financial Activities', 'pct_Professional & Business Services',
#        'pct_Education & Health Services', 'pct_Leisure & Hospitality',
#        'pct_Other Services', 'pct_Government',
#        'pct_Mining, Logging and Construction'],
#       dtype='object')

# %% [markdown]
# #### The following functions are used within the Pipelines for either the scaled data or FeatureUnion

# %%
def get_scaled_columns(df):
    return pd.DataFrame(df[target_columns[0]])

get_scaled_transformer = FunctionTransformer(get_scaled_columns, validate=False)

# %%
def get_non_scaled_columns(df):
    return df[target_columns[1:]]

get_non_scaled_transformer = FunctionTransformer(get_non_scaled_columns, validate=False)

# %%
pipe_scaler = Pipeline([
    ('scale_transform', get_scaled_transformer),
    ('ss', StandardScaler())
])

# %%
union = FeatureUnion([
    ('vect_pipe', pipe_scaler),
    ('other_cols', get_non_scaled_transformer)
])

union_res = union.fit_transform(df_2018)

# %%
df_2018_sc = pd.DataFrame(union_res, columns=target_columns)
df_2018_sc.head()
# Out:
#    Total Nonfarm  pct_Manufacturing  pct_Trade, Transportation, and Utils  \
# 0      -0.273332             0.1305                                0.1874
# 1      -0.810216             0.0381                                0.1966
# 2      -0.019835             0.0600                                0.1870
# 3      -0.516615             0.1269                                0.1999
# 4       4.451965             0.0771                                0.1774
#
#    pct_Information  pct_Financial Activities  \
# 0           0.0103                    0.0470
# 1           0.0171                    0.0359
# 2           0.0166                    0.0770
# 3           0.0098                    0.0482
# 4           0.0316                    0.0488
#
#    pct_Professional & Business Services  pct_Education & Health Services  \
# 0                                0.1194                           0.1198
# 1                                0.0835                           0.1539
# 2                                0.1519                           0.1559
# 3                                0.1147                           0.1511
# 4                                0.1555                           0.1585
#
#    pct_Leisure & Hospitality  pct_Other Services  pct_Government  \
# 0                     0.1006              0.0475          0.1890
# 1                     0.1088              0.0337          0.2453
# 2                     0.1141              0.0323          0.1455
# 3                     0.0933              0.0439          0.1673
# 4                     0.1161              0.0333          0.1503
#
#    pct_Mining, Logging and Construction
# 0                                0.0485
# 1                                0.0870
# 2                                0.0596
# 3                                0.0448
# 4                                0.0514

# %% [markdown]
# #### DBScan Clustering
# Using DBScan to determine how best to cluster the data.

# %%
from sklearn.cluster import DBSCAN
def find_best_silhouette(X):     
    max_score=-1
    for eps in np.linspace(0.2, 5, 20):
        for minsamples in range(2, round(len(X) / 2)):
            dbscan = DBSCAN(eps=eps, min_samples=minsamples)
            dbscan.fit(X)
            if len(set(dbscan.labels_)) > 2:
                score = silhouette_score(X, dbscan.labels_)
                if -1 in set(dbscan.labels_):
                    nclusters = len(set(dbscan.labels_)) - 1
                else:
                    nclusters = len(set(dbscan.labels_)) 
                if score > max_score:
                    max_score = score
                    best_eps = eps
                    best_minsamples = minsamples
                    best_clusters = nclusters
    print(f'Best silhouette score was {round(max_score, 5)}')
    print(f'Best eps was {round(best_eps, 2)}')
    print(f'Best min_samples was {best_minsamples}.')
    print(f'Model found {best_clusters} clusters.')
    return
find_best_silhouette(df_2018_sc)
# Out:
# Best silhouette score was 0.67505
# Best eps was 0.45
# Best min_samples was 2.
# Model found 2 clusters.

# %% [markdown]
# #### KMeans Clustering

# %% [markdown]
# ##### Looping through KMeans clusters to determine best Silhoutte Score

# %%
silhouette_list = []

for k in range(2, 25):
    kmeans = KMeans(n_clusters=k, random_state=13)
    kmeans.fit(df_2018_sc)
    silhouette_list.append(silhouette_score(df_2018_sc, kmeans.labels_))
silhouette_list
# Out:
# [0.7725317579175214,
#  0.5963666675122845,
#  0.5926641035779244,
#  0.5261620829452,
#  0.5120651335367421,
#  0.5151200064843636,
#  0.553118277856621,
#  0.48382067140594986,
#  0.4560331539327963,
#  0.45318475173191164,
#  0.4270012681119023,
#  0.42812218957548565,
#  0.357374064726818,
#  0.3365927314742852,
#  0.3020729677933735,
#  0.2967180903206686,
#  0.30771469355008557,
#  0.29013064124215454,
#  0.29598375716184433,
#  0.28097741442459867,
#  0.24502676837586215,
#  0.2633169515505015,
#  0.24556009471646326]

# %% [markdown]
# #### Looping through KMeans clusters to determine best Inertia Score

# %%
inertias = []
ks = list(range(2,25))

for k in ks:
    km = KMeans(n_clusters=k, random_state=13)
    km.fit(df_2018_sc)
    inertias.append(km.inertia_)
plt.plot(ks, inertias);

# %% [markdown]
# #### Simplified version of Scaling & FeatureUnion for 2021

# %%
union_res_2021 = union.fit_transform(df_2021)

# %%
df_2021_sc = pd.DataFrame(union_res_2021, columns=target_columns)
df_2021_sc.head()
# Out:
#    Total Nonfarm  pct_Manufacturing  pct_Trade, Transportation, and Utils  \
# 0      -0.262526             0.1292                                0.1934
# 1      -0.813071             0.0403                                0.1966
# 2       0.029844             0.0611                                0.1974
# 3      -0.503555             0.1225                                0.1999
# 4       4.406927             0.0762                                0.1816
#
#    pct_Information  pct_Financial Activities  \
# 0           0.0098                    0.0481
# 1           0.0154                    0.0347
# 2           0.0160                    0.0830
# 3           0.0091                    0.0514
# 4           0.0339                    0.0493
#
#    pct_Professional & Business Services  pct_Education & Health Services  \
# 0                                0.1228                           0.1172
# 1                                0.0852                           0.1627
# 2                                0.1504                           0.1570
# 3                                0.1139                           0.1521
# 4                                0.1618                           0.1681
#
#    pct_Leisure & Hospitality  pct_Other Services  pct_Government  \
# 0                     0.0924              0.0466          0.1901
# 1                     0.0978              0.0337          0.2486
# 2                     0.1028              0.0308          0.1374
# 3                     0.0903              0.0522          0.1614
# 4                     0.0976              0.0299          0.1477
#
#    pct_Mining, Logging and Construction
# 0                                0.0505
# 1                                0.0850
# 2                                0.0641
# 3                                0.0472
# 4                                0.0538

# %% [markdown]
# ##### Looping through KMeans clusters to determine best Silhoutte Score

# %%
silhouette_list = []

for k in range(2, 25):
    kmeans = KMeans(n_clusters=k, random_state=13)
    kmeans.fit(df_2021_sc)
    silhouette_list.append(silhouette_score(df_2021_sc, kmeans.labels_))
silhouette_list
# Out:
# [0.7755987844721923,
#  0.6008119056628506,
#  0.604852483130968,
#  0.5455708943288491,
#  0.5336321079938592,
#  0.537554441838545,
#  0.5615621790548438,
#  0.479636222215527,
#  0.44039647703889173,
#  0.44688226260481606,
#  0.35312787178551724,
#  0.3514656887349095,
#  0.3419796350092676,
#  0.3369562471452749,
#  0.3344399411653107,
#  0.30649916539184335,
#  0.3151808702140301,
#  0.3000719457702771,
#  0.30131219479653965,
#  0.2707627125021187,
#  0.2803145012355155,
#  0.2688480550785032,
#  0.28122144691771217]

# %% [markdown]
# ##### Looping through KMeans clusters to determine best Inertia Score

# %%
inertias = []
ks = list(range(2,25))

for k in ks:
    km = KMeans(n_clusters=k, random_state=13)
    km.fit(df_2021_sc)
    inertias.append(km.inertia_)
plt.plot(ks, inertias);

# %% [markdown]
# #### Instantiate & Fit KMeans Models

# %%
df_2018_clusters = df_2018.copy()
df_2021_clusters = df_2021.copy()

# %%
km = KMeans(n_clusters=4, random_state=13)
km.fit(df_2018_sc)
df_2018_clusters['clusters-4'] = km.labels_
km.fit(df_2021_sc)
df_2021_clusters['clusters-4'] = km.labels_
df_2018_clusters.head()
# Out:
#             Total Nonfarm  Manufacturing  Trade, Transportation, and Utils  \
# Alabama          2046.258        266.992                           383.467
# Alaska            327.658         12.500                            64.408
# Arizona          2857.717        171.450                           534.525
# Arkansas         1267.492        160.800                           253.408
# California      17172.225       1323.550                          3045.983
#
#             Information  Financial Activities  \
# Alabama          21.092                96.258
# Alaska            5.608                11.767
# Arizona          47.558               220.008
# Arkansas         12.433                61.058
# California      542.850               837.875
#
#             Professional & Business Services  Education & Health Services  \
# Alabama                              244.242                      245.167
# Alaska                                27.358                       50.442
# Arizona                              434.033                      445.417
# Arkansas                             145.425                      191.575
# California                          2670.217                     2722.283
#
#             Leisure & Hospitality  Other Services  Government  ...  \
# Alabama                   205.933          97.117     386.792  ...
# Alaska                     35.650          11.058      80.375  ...
# Arizona                   325.975          92.442     415.858  ...
# Arkansas                  118.267          55.650     212.108  ...
# California               1993.142         571.667    2581.483  ...
#
#             pct_Trade, Transportation, and Utils  pct_Information  \
# Alabama                                   0.1874           0.0103
# Alaska                                    0.1966           0.0171
# Arizona                                   0.1870           0.0166
# Arkansas                                  0.1999           0.0098
# California                                0.1774           0.0316
#
#             pct_Financial Activities  pct_Professional & Business Services  \
# Alabama                       0.0470                                0.1194
# Alaska                        0.0359                                0.0835
# Arizona                       0.0770                                0.1519
# Arkansas                      0.0482                                0.1147
# California                    0.0488                                0.1555
#
#             pct_Education & Health Services  pct_Leisure & Hospitality  \
# Alabama                              0.1198                     0.1006
# Alaska                               0.1539                     0.1088
# Arizona                              0.1559                     0.1141
# Arkansas                             0.1511                     0.0933
# California                           0.1585                     0.1161
#
#             pct_Other Services  pct_Government  \
# Alabama                 0.0475          0.1890
# Alaska                  0.0337          0.2453
# Arizona                 0.0323          0.1455
# Arkansas                0.0439          0.1673
# California              0.0333          0.1503
#
#             pct_Mining, Logging and Construction  clusters-4
# Alabama                                   0.0485           0
# Alaska                                    0.0870           0
# Arizona                                   0.0596           2
# Arkansas                                  0.0448           0
# California                                0.0514           3
#
# [5 rows x 22 columns]

# %% [markdown]
# ##### Viewing outputs by cluster

# %%
# 4 clusters sil score = 0.545
for r in range(4):
    print(f'cluster {r}')
    print(df_2018_clusters[df_2018_clusters['clusters-4']==r].index)
    print()
# Out:
# cluster 0
# Index(['Alabama', 'Alaska', 'Arkansas', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Hawaii', 'Idaho', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Mississippi', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Mexico', 'North Dakota', 'Oklahoma', 'Oregon',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Utah', 'Vermont',
#        'West Virginia', 'Wyoming'],
#       dtype='object')
#
# cluster 1
# Index(['Florida', 'New York', 'Texas'], dtype='object')
#
# cluster 2
# Index(['Arizona', 'Colorado', 'Georgia', 'Illinois', 'Indiana', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Missouri', 'New Jersey',
#        'North Carolina', 'Ohio', 'Pennsylvania', 'Tennessee', 'Virginia',
#        'Washington', 'Wisconsin'],
#       dtype='object')
#
# cluster 3
# Index(['California'], dtype='object')

# %%
# 3 clusters sil score = 0.55
km = KMeans(n_clusters=3, random_state=13)
km.fit(df_2018_sc)
df_2018_clusters['clusters-3'] = km.labels_
for r in range(3):
    print(f'cluster {r}')
    print(df_2018_clusters[df_2018_clusters['clusters-3']==r].index)
    print()
# Out:
# cluster 0
# Index(['Arizona', 'Colorado', 'Georgia', 'Illinois', 'Indiana', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Missouri', 'New Jersey',
#        'North Carolina', 'Ohio', 'Pennsylvania', 'Tennessee', 'Virginia',
#        'Washington', 'Wisconsin'],
#       dtype='object')
#
# cluster 1
# Index(['California', 'Florida', 'New York', 'Texas'], dtype='object')
#
# cluster 2
# Index(['Alabama', 'Alaska', 'Arkansas', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Hawaii', 'Idaho', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Mississippi', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Mexico', 'North Dakota', 'Oklahoma', 'Oregon',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Utah', 'Vermont',
#        'West Virginia', 'Wyoming'],
#       dtype='object')

# %%
# 5 clusters sil score = 0.449
km = KMeans(n_clusters=5, random_state=13)
km.fit(df_2018_sc)
df_2018_clusters['clusters-5'] = km.labels_
for r in range(5):
    print(f'cluster {r}')
    print(df_2018_clusters[df_2018_clusters['clusters-5']==r].index)
    print()
# Out:
# cluster 0
# Index(['Alabama', 'Arizona', 'Colorado', 'Indiana', 'Kentucky', 'Louisiana',
#        'Maryland', 'Massachusetts', 'Minnesota', 'Missouri', 'Oregon',
#        'South Carolina', 'Tennessee', 'Washington', 'Wisconsin'],
#       dtype='object')
#
# cluster 1
# Index(['Florida', 'New York', 'Texas'], dtype='object')
#
# cluster 2
# Index(['Georgia', 'Illinois', 'Michigan', 'New Jersey', 'North Carolina',
#        'Ohio', 'Pennsylvania', 'Virginia'],
#       dtype='object')
#
# cluster 3
# Index(['Alaska', 'Arkansas', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Hawaii', 'Idaho', 'Iowa', 'Kansas', 'Maine', 'Mississippi', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Mexico', 'North Dakota',
#        'Oklahoma', 'Rhode Island', 'South Dakota', 'Utah', 'Vermont',
#        'West Virginia', 'Wyoming'],
#       dtype='object')
#
# cluster 4
# Index(['California'], dtype='object')

# %%
# Save dataframe to CSV in the source_data directory
df_2018_clusters.to_csv('./source_data/2018_with_clusters.csv', index_label='State')

# %% [markdown]
# ##### Visualize statistics by cluster in a table format

# %%
# Used to easily visualize output of following cell
pd.set_option('display.max_rows', None)

# %% [markdown]
# ##### To change which cluster to analyze, change the `by='clusters-5'` to `clusters-4` or `clusters-3`

# %%
df_2018_clusters.groupby(by='clusters-5').describe().T
# Out:
# clusters-5                                            0             1  \
# Total Nonfarm                        count    15.000000      3.000000
#                                      mean   2698.308867  10330.241667
#                                      std     557.807815   1952.665543
#                                      min    1922.950000   8780.950000
#                                      25%    2100.541500   9233.575000
#                                      50%    2857.717000   9686.200000
#                                      75%    3023.800000  11104.887500
#                                      max    3648.558000  12523.575000
# Manufacturing                        count    15.000000      3.000000
#                                      mean    268.388333    566.314000
#                                      std     120.429876    275.669210
#                                      min     110.075000    372.908000
#                                      25%     183.283500    408.487500
#                                      50%     251.658000    444.067000
#                                      75%     304.820500    663.017000
#                                      max     542.300000    881.967000
# Trade, Transportation, and Utils     count    15.000000      3.000000
#                                      mean    497.341600   1941.267000
#                                      std      94.821875    476.373764
#                                      min     352.667000   1566.542000
#                                      25%     403.954000   1673.217000
#                                      50%     533.767000   1779.892000
#                                      75%     562.516500   2128.629500
#                                      max     636.008000   2477.367000
# Information                          count    15.000000      3.000000
#                                      mean     48.877733    209.441667
#                                      std      30.754163     72.336813
#                                      min      21.092000    139.492000
#                                      25%      29.233000    172.187500
#                                      50%      45.050000    204.883000
#                                      75%      48.354000    244.416500
#                                      max     134.200000    283.950000
# Financial Activities                 count    15.000000      3.000000
#                                      mean    148.886133    692.675000
#                                      std      44.069175    104.961752
#                                      min      93.183000    575.800000
#                                      25%     103.154000    649.562500
#                                      50%     152.975000    723.325000
#                                      75%     171.862500    751.112500
#                                      max     224.067000    778.900000
# Professional & Business Services     count    15.000000      3.000000
#                                      mean    359.616067   1478.316667
#                                      std     104.176948    232.548072
#                                      min     213.133000   1327.083000
#                                      25%     271.646000   1344.429000
#                                      50%     382.075000   1361.775000
#                                      75%     423.866500   1553.933500
#                                      max     588.408000   1746.092000
# Education & Health Services          count    15.000000      3.000000
#                                      mean    422.789533   1692.563667
#                                      std     142.254054    384.348395
#                                      min     245.167000   1305.058000
#                                      25%     310.408500   1502.008000
#                                      50%     445.417000   1698.958000
#                                      75%     478.900000   1886.316500
#                                      max     796.992000   2073.675000
# Leisure & Hospitality                count    15.000000      3.000000
#                                      mean    286.036067   1181.969333
#                                      std      54.805839    202.494366
#                                      min     198.092000    959.967000
#                                      25%     250.200000   1094.687500
#                                      50%     282.425000   1229.408000
#                                      75%     331.791500   1292.970500
#                                      max     375.383000   1356.533000
# Other Services                       count    15.000000      3.000000
#                                      mean    105.400000    401.163667
#                                      std      26.152491     43.036175
#                                      min      64.408000    353.075000
#                                      25%      85.125000    383.716500
#                                      50%     113.942000    414.358000
#                                      75%     120.200000    425.208000
#                                      max     152.167000    436.058000
# Government                           count    15.000000      3.000000
#                                      mean    416.065067   1519.614000
#                                      std      73.971126    421.877961
#                                      min     294.942000   1115.008000
#                                      25%     377.342000   1300.987500
#                                      50%     425.767000   1486.967000
#                                      75%     440.637500   1721.917000
#                                      max     587.208000   1956.867000
# Mining, Logging and Construction     count    15.000000      3.000000
#                                      mean    144.907733    646.858333
#                                      std      38.432036    302.134033
#                                      min      88.092000    406.266000
#                                      25%     119.904000    477.312500
#                                      50%     128.917000    548.359000
#                                      75%     167.529000    767.154500
#                                      max     219.417000    985.950000
# pct_Manufacturing                    count    15.000000      3.000000
#                                      mean      0.100173      0.052900
#                                      std       0.038836      0.015245
#                                      min       0.040000      0.042500
#                                      25%       0.067300      0.044150
#                                      50%       0.101500      0.045800
#                                      75%       0.123150      0.058100
#                                      max       0.172800      0.070400
# pct_Trade, Transportation, and Utils count    15.000000      3.000000
#                                      mean      0.185327      0.187400
#                                      std       0.012306      0.022391
#                                      min       0.159000      0.161700
#                                      25%       0.180650      0.179750
#                                      50%       0.187000      0.197800
#                                      75%       0.189400      0.200250
#                                      max       0.209000      0.202700
# pct_Information                      count    15.000000      3.000000
#                                      mean      0.017300      0.020533
#                                      std       0.007978      0.007596
#                                      min       0.009300      0.015900
#                                      25%       0.012250      0.016150
#                                      50%       0.015800      0.016400
#                                      75%       0.017450      0.022850
#                                      max       0.039500      0.029300
# pct_Financial Activities             count    15.000000      3.000000
#                                      mean      0.054633      0.067500
#                                      std       0.008925      0.006463
#                                      min       0.044500      0.062200
#                                      25%       0.047750      0.063900
#                                      50%       0.053100      0.065600
#                                      75%       0.060450      0.070150
#                                      max       0.077000      0.074700
# pct_Professional & Business Services count    15.000000      3.000000
#                                      mean      0.131967      0.143833
#                                      std       0.019118      0.009831
#                                      min       0.107100      0.137000
#                                      25%       0.115900      0.138200
#                                      50%       0.129800      0.139400
#                                      75%       0.144100      0.147250
#                                      max       0.164500      0.155100
# pct_Education & Health Services      count    15.000000      3.000000
#                                      mean      0.154147      0.166133
#                                      std       0.025643      0.042038
#                                      min       0.117800      0.135700
#                                      25%       0.143800      0.142150
#                                      50%       0.153400      0.148600
#                                      75%       0.163350      0.181350
#                                      max       0.218400      0.214100
# pct_Leisure & Hospitality            count    15.000000      3.000000
#                                      mean      0.106713      0.115800
#                                      std       0.009716      0.021457
#                                      min       0.092300      0.099100
#                                      25%       0.100550      0.103700
#                                      50%       0.102900      0.108300
#                                      75%       0.112100      0.124150
#                                      max       0.124500      0.140000
# pct_Other Services                   count    15.000000      3.000000
#                                      mean      0.038940      0.039267
#                                      std       0.005050      0.004081
#                                      min       0.032300      0.034800
#                                      25%       0.036000      0.037500
#                                      50%       0.038400      0.040200
#                                      75%       0.040450      0.041500
#                                      max       0.051100      0.042800
# pct_Government                       count    15.000000      3.000000
#                                      mean      0.156173      0.145600
#                                      std       0.018335      0.016169
#                                      min       0.124200      0.127000
#                                      25%       0.142900      0.140250
#                                      50%       0.153400      0.153500
#                                      75%       0.168250      0.154900
#                                      max       0.189000      0.156300
# pct_Mining, Logging and Construction count    15.000000      3.000000
#                                      mean      0.054600      0.061000
#                                      std       0.014647      0.018440
#                                      min       0.042000      0.041900
#                                      25%       0.043850      0.052150
#                                      50%       0.048500      0.062400
#                                      75%       0.059700      0.070550
#                                      max       0.094800      0.078700
# clusters-4                           count    15.000000      3.000000
#                                      mean      1.333333      1.000000
#                                      std       0.975900      0.000000
#                                      min       0.000000      1.000000
#                                      25%       0.000000      1.000000
#                                      50%       2.000000      1.000000
#                                      75%       2.000000      1.000000
#                                      max       2.000000      1.000000
# clusters-3                           count    15.000000      3.000000
#                                      mean      0.666667      1.000000
#                                      std       0.975900      0.000000
#                                      min       0.000000      1.000000
#                                      25%       0.000000      1.000000
#                                      50%       0.000000      1.000000
#                                      75%       2.000000      1.000000
#                                      max       2.000000      1.000000
#
# clusters-5                                            2            3  \
# Total Nonfarm                        count     8.000000    24.000000
#                                      mean   4912.733625   876.760458
#                                      std     843.266249   469.277999
#                                      min    4011.292000   285.942000
#                                      25%    4359.848250   474.433500
#                                      50%    4513.629500   732.195500
#                                      75%    5674.867000  1296.487750
#                                      max    6102.525000  1699.275000
# Manufacturing                        count     8.000000    24.000000
#                                      mean    481.883250    73.977833
#                                      std     171.446818    62.908929
#                                      min     240.500000     1.342000
#                                      25%     365.764250    26.800000
#                                      50%     522.908500    49.558500
#                                      75%     597.518750   135.010500
#                                      max     698.783000   222.617000
# Trade, Transportation, and Utils     count     8.000000    24.000000
#                                      mean    932.571750   159.722917
#                                      std     181.446669    91.663845
#                                      min     661.100000    33.208000
#                                      25%     822.531000    85.074750
#                                      50%     906.195500   133.883500
#                                      75%    1049.920750   253.860250
#                                      max    1211.792000   312.533000
# Information                          count     8.000000    24.000000
#                                      mean     79.699125    12.731917
#                                      std      18.711203     8.888056
#                                      min      55.967000     3.550000
#                                      25%      70.058500     6.154000
#                                      50%      73.146000    10.129000
#                                      75%      88.381500    17.904000
#                                      max     115.792000    38.500000
# Financial Activities                 count     8.000000    24.000000
#                                      mean    275.975000    47.930583
#                                      std      65.217527    30.776761
#                                      min     208.275000    11.100000
#                                      25%     237.106250    29.300250
#                                      50%     249.654000    35.050000
#                                      75%     312.612750    69.142000
#                                      max     402.775000   125.467000
# Professional & Business Services     count     8.000000    24.000000
#                                      mean    739.073000   103.729958
#                                      std     100.211776    63.933182
#                                      min     635.883000    18.717000
#                                      25%     672.862750    58.137500
#                                      50%     718.108500    88.787500
#                                      75%     763.775000   151.098000
#                                      max     948.167000   221.092000
# Education & Health Services          count     8.000000    24.000000
#                                      mean    784.543750   135.058375
#                                      std     246.248408    72.025503
#                                      min     546.233000    28.250000
#                                      25%     605.654500    79.241750
#                                      50%     696.450000   127.721000
#                                      75%     931.012250   164.775250
#                                      max    1274.750000   344.792000
# Leisure & Hospitality                count     8.000000    24.000000
#                                      mean    497.502000   100.999750
#                                      std      83.344527    68.100483
#                                      min     387.550000    35.650000
#                                      25%     427.839500    57.360500
#                                      50%     495.900000    79.600000
#                                      75%     568.268500   130.758500
#                                      max     617.550000   352.717000
# Other Services                       count     8.000000    24.000000
#                                      mean    198.107250    34.254875
#                                      std      41.104885    19.471823
#                                      min     160.358000    10.292000
#                                      25%     164.821000    18.814750
#                                      50%     184.512500    27.133500
#                                      75%     223.670750    43.933000
#                                      max     260.392000    76.783000
# Government                           count     8.000000    24.000000
#                                      mean    707.757250   156.083708
#                                      std      75.968260    82.364797
#                                      min     603.342000    56.233000
#                                      25%     669.793500    82.031000
#                                      50%     712.966500   139.121000
#                                      75%     742.850000   236.868500
#                                      max     819.775000   348.450000
# Mining, Logging and Construction     count     8.000000    24.000000
#                                      mean    215.621000    52.270833
#                                      std      38.579675    31.091657
#                                      min     159.275000    15.650000
#                                      25%     197.893500    28.349500
#                                      50%     216.321000    49.125000
#                                      75%     233.246500    64.102000
#                                      max     284.525000   133.275000
# pct_Manufacturing                    count     8.000000    24.000000
#                                      mean      0.096725     0.075992
#                                      std       0.028594     0.036516
#                                      min       0.060000     0.001700
#                                      25%       0.081900     0.042300
#                                      50%       0.095600     0.082400
#                                      75%       0.110750     0.098325
#                                      max       0.142000     0.140600
# pct_Trade, Transportation, and Utils count     8.000000    24.000000
#                                      mean      0.189525     0.181721
#                                      std       0.015124     0.032839
#                                      min       0.164800     0.041900
#                                      25%       0.182750     0.176325
#                                      50%       0.186500     0.189050
#                                      75%       0.200275     0.197400
#                                      max       0.211700     0.216100
# pct_Information                      count     8.000000    24.000000
#                                      mean      0.016413     0.014150
#                                      std       0.004090     0.004181
#                                      min       0.012600     0.008800
#                                      25%       0.013900     0.011675
#                                      50%       0.016050     0.013250
#                                      75%       0.016975     0.015000
#                                      max       0.025500     0.025400
# pct_Financial Activities             count     8.000000    24.000000
#                                      mean      0.055813     0.053721
#                                      std       0.005190     0.015878
#                                      min       0.049900     0.035900
#                                      25%       0.053475     0.041075
#                                      50%       0.054200     0.049850
#                                      75%       0.056775     0.060125
#                                      max       0.066000     0.103600
# pct_Professional & Business Services count     8.000000    24.000000
#                                      mean      0.152087     0.113379
#                                      std       0.017810     0.030844
#                                      min       0.131400     0.065500
#                                      25%       0.139725     0.090775
#                                      50%       0.152200     0.114350
#                                      75%       0.157325     0.128600
#                                      max       0.186900     0.212000
# pct_Education & Health Services      count     8.000000    24.000000
#                                      mean      0.157375     0.157992
#                                      std       0.026578     0.030212
#                                      min       0.129700     0.098800
#                                      25%       0.136175     0.140875
#                                      50%       0.153850     0.153200
#                                      75%       0.167950     0.173675
#                                      max       0.212100     0.213300
# pct_Leisure & Hospitality            count     8.000000    24.000000
#                                      mean      0.101438     0.116254
#                                      std       0.006239     0.036558
#                                      min       0.093100     0.090500
#                                      25%       0.097300     0.096900
#                                      50%       0.101550     0.107850
#                                      75%       0.103700     0.117000
#                                      max       0.111900     0.255000
# pct_Other Services                   count     8.000000    24.000000
#                                      mean      0.040325     0.040071
#                                      std       0.004615     0.013460
#                                      min       0.035400     0.027200
#                                      25%       0.037100     0.034575
#                                      50%       0.039700     0.036050
#                                      75%       0.042100     0.040500
#                                      max       0.049400     0.096800
# pct_Government                       count     8.000000    24.000000
#                                      mean      0.146212     0.183271
#                                      std       0.019062     0.041526
#                                      min       0.117000     0.117000
#                                      25%       0.136700     0.162250
#                                      50%       0.143150     0.179800
#                                      75%       0.154700     0.206850
#                                      max       0.180200     0.300600
# pct_Mining, Logging and Construction count     8.000000    24.000000
#                                      mean      0.044100     0.063458
#                                      std       0.005251     0.026818
#                                      min       0.038300     0.019700
#                                      25%       0.039525     0.047425
#                                      50%       0.043550     0.053500
#                                      75%       0.048075     0.076575
#                                      max       0.051400     0.143600
# clusters-4                           count     8.000000    24.000000
#                                      mean      2.000000     0.000000
#                                      std       0.000000     0.000000
#                                      min       2.000000     0.000000
#                                      25%       2.000000     0.000000
#                                      50%       2.000000     0.000000
#                                      75%       2.000000     0.000000
#                                      max       2.000000     0.000000
# clusters-3                           count     8.000000    24.000000
#                                      mean      0.000000     2.000000
#                                      std       0.000000     0.000000
#                                      min       0.000000     2.000000
#                                      25%       0.000000     2.000000
#                                      50%       0.000000     2.000000
#                                      75%       0.000000     2.000000
#                                      max       0.000000     2.000000
#
# clusters-5                                           4
# Total Nonfarm                        count      1.0000
#                                      mean   17172.2250
#                                      std           NaN
#                                      min    17172.2250
#                                      25%    17172.2250
#                                      50%    17172.2250
#                                      75%    17172.2250
#                                      max    17172.2250
# Manufacturing                        count      1.0000
#                                      mean    1323.5500
#                                      std           NaN
#                                      min     1323.5500
#                                      25%     1323.5500
#                                      50%     1323.5500
#                                      75%     1323.5500
#                                      max     1323.5500
# Trade, Transportation, and Utils     count      1.0000
#                                      mean    3045.9830
#                                      std           NaN
#                                      min     3045.9830
#                                      25%     3045.9830
#                                      50%     3045.9830
#                                      75%     3045.9830
#                                      max     3045.9830
# Information                          count      1.0000
#                                      mean     542.8500
#                                      std           NaN
#                                      min      542.8500
#                                      25%      542.8500
#                                      50%      542.8500
#                                      75%      542.8500
#                                      max      542.8500
# Financial Activities                 count      1.0000
#                                      mean     837.8750
#                                      std           NaN
#                                      min      837.8750
#                                      25%      837.8750
#                                      50%      837.8750
#                                      75%      837.8750
#                                      max      837.8750
# Professional & Business Services     count      1.0000
#                                      mean    2670.2170
#                                      std           NaN
#                                      min     2670.2170
#                                      25%     2670.2170
#                                      50%     2670.2170
#                                      75%     2670.2170
#                                      max     2670.2170
# Education & Health Services          count      1.0000
#                                      mean    2722.2830
#                                      std           NaN
#                                      min     2722.2830
#                                      25%     2722.2830
#                                      50%     2722.2830
#                                      75%     2722.2830
#                                      max     2722.2830
# Leisure & Hospitality                count      1.0000
#                                      mean    1993.1420
#                                      std           NaN
#                                      min     1993.1420
#                                      25%     1993.1420
#                                      50%     1993.1420
#                                      75%     1993.1420
#                                      max     1993.1420
# Other Services                       count      1.0000
#                                      mean     571.6670
#                                      std           NaN
#                                      min      571.6670
#                                      25%      571.6670
#                                      50%      571.6670
#                                      75%      571.6670
#                                      max      571.6670
# Government                           count      1.0000
#                                      mean    2581.4830
#                                      std           NaN
#                                      min     2581.4830
#                                      25%     2581.4830
#                                      50%     2581.4830
#                                      75%     2581.4830
#                                      max     2581.4830
# Mining, Logging and Construction     count      1.0000
#                                      mean     883.1750
#                                      std           NaN
#                                      min      883.1750
#                                      25%      883.1750
#                                      50%      883.1750
#                                      75%      883.1750
#                                      max      883.1750
# pct_Manufacturing                    count      1.0000
#                                      mean       0.0771
#                                      std           NaN
#                                      min        0.0771
#                                      25%        0.0771
#                                      50%        0.0771
#                                      75%        0.0771
#                                      max        0.0771
# pct_Trade, Transportation, and Utils count      1.0000
#                                      mean       0.1774
#                                      std           NaN
#                                      min        0.1774
#                                      25%        0.1774
#                                      50%        0.1774
#                                      75%        0.1774
#                                      max        0.1774
# pct_Information                      count      1.0000
#                                      mean       0.0316
#                                      std           NaN
#                                      min        0.0316
#                                      25%        0.0316
#                                      50%        0.0316
#                                      75%        0.0316
#                                      max        0.0316
# pct_Financial Activities             count      1.0000
#                                      mean       0.0488
#                                      std           NaN
#                                      min        0.0488
#                                      25%        0.0488
#                                      50%        0.0488
#                                      75%        0.0488
#                                      max        0.0488
# pct_Professional & Business Services count      1.0000
#                                      mean       0.1555
#                                      std           NaN
#                                      min        0.1555
#                                      25%        0.1555
#                                      50%        0.1555
#                                      75%        0.1555
#                                      max        0.1555
# pct_Education & Health Services      count      1.0000
#                                      mean       0.1585
#                                      std           NaN
#                                      min        0.1585
#                                      25%        0.1585
#                                      50%        0.1585
#                                      75%        0.1585
#                                      max        0.1585
# pct_Leisure & Hospitality            count      1.0000
#                                      mean       0.1161
#                                      std           NaN
#                                      min        0.1161
#                                      25%        0.1161
#                                      50%        0.1161
#                                      75%        0.1161
#                                      max        0.1161
# pct_Other Services                   count      1.0000
#                                      mean       0.0333
#                                      std           NaN
#                                      min        0.0333
#                                      25%        0.0333
#                                      50%        0.0333
#                                      75%        0.0333
#                                      max        0.0333
# pct_Government                       count      1.0000
#                                      mean       0.1503
#                                      std           NaN
#                                      min        0.1503
#                                      25%        0.1503
#                                      50%        0.1503
#                                      75%        0.1503
#                                      max        0.1503
# pct_Mining, Logging and Construction count      1.0000
#                                      mean       0.0514
#                                      std           NaN
#                                      min        0.0514
#                                      25%        0.0514
#                                      50%        0.0514
#                                      75%        0.0514
#                                      max        0.0514
# clusters-4                           count      1.0000
#                                      mean       3.0000
#                                      std           NaN
#                                      min        3.0000
#                                      25%        3.0000
#                                      50%        3.0000
#                                      75%        3.0000
#                                      max        3.0000
# clusters-3                           count      1.0000
#                                      mean       1.0000
#                                      std           NaN
#                                      min        1.0000
#                                      25%        1.0000
#                                      50%        1.0000
#                                      75%        1.0000
#                                      max        1.0000

# %% [markdown]
# #### Economic Breakdown by Cluster

# %%
cluster_industries = df_2018_clusters.groupby(by='clusters-5').agg('mean').T.iloc[11:-2,::]
cluster_industries.rename(index={'pct_Manufacturing':'Manufacturing',
                                 'pct_Trade, Transportation, and Utils':'Trade, Transportation, Utils',
                                 'pct_Information':'Information',
                                 'pct_Financial Activities':'Financial Activites',
                                 'pct_Professional & Business Services':'Professional & Business Services',
                                 'pct_Education & Health Services':'Education & Health Services',
                                 'pct_Leisure & Hospitality':'Leisure & Hospitality',
                                 'pct_Other Services':'Other Services',
                                 'pct_Government':'Government',
                                 'pct_Mining, Logging and Construction':'Mining, Logging, & Construction'}, inplace = True)

# %%
cluster_industries.plot.barh(figsize = (16,12), width = 0.8, color=['turquoise', 'orange',  'green', 'darkkhaki', 'red'], alpha=0.5);
plt.yticks(fontsize = '14');
plt.xticks(fontsize = '14');
plt.rcParams['axes.spines.left'] = False
# plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.spines.bottom'] = False
# plt.spines['right'].set_visible(False)
# plt.spines['bottom'].set_visible(False)
# plt.spines['left'].set_visible(False)
plt.title('Economic Industry Breakdown per Cluster', fontsize = '22')
plt.xlabel('Percentage', fontsize = '18')
plt.ylabel('Industries', fontsize = '18');
plt.legend(title = 'Clusters');
