# %%
#imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
econ_2018 = pd.read_csv('./csv/economies_2018.csv', index_col = 0)

# %%
econ_2018.head()
# Out:
#             Total Nonfarm  Mining and Logging  Construction  Manufacturing  \
# State
# Alabama          2046.258              10.000        89.200        266.992
# Alaska            327.658              12.658        15.833         12.500
# Arizona          2857.717              13.050       157.400        171.450
# Arkansas         1267.492               5.933        50.833        160.800
# California      17172.225              22.492       860.683       1323.550
#
#             Trade, Transportation, and Utils  Information  \
# State
# Alabama                              383.467       21.092
# Alaska                                64.408        5.608
# Arizona                              534.525       47.558
# Arkansas                             253.408       12.433
# California                          3045.983      542.850
#
#             Financial Activities  Professional & Business Services  \
# State
# Alabama                   96.258                           244.242
# ...

# %%
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn.impute import KNNImputer

# %%
it_imp = IterativeImputer(estimator = LinearRegression())
it_imp_econ_2018 = it_imp.fit_transform(econ_2018)

# %%
econ_2018['composite'] = (econ_2018['Mining and Logging'] / (econ_2018['Mining and Logging'] + econ_2018['Construction']))

# %%
econ_2018['Mining, Logging and Construction'].fillna(econ_2018['Mining and Logging'] + econ_2018['Construction'], inplace=True)

# %%
econ_2018
# Out:
#                       Total Nonfarm  Mining and Logging  Construction  \
# State
# Alabama                    2046.258              10.000        89.200
# Alaska                      327.658              12.658        15.833
# Arizona                    2857.717              13.050       157.400
# Arkansas                   1267.492               5.933        50.833
# California                17172.225              22.492       860.683
# Colorado                   2726.925              28.525       173.125
# Connecticut                1699.275               0.567        58.767
# Delaware                    461.508                 NaN           NaN
# District of Columbia        792.958                 NaN           NaN
# Florida                    8780.950               5.742       542.617
# Georgia                    4535.942               9.533       195.525
# Hawaii                      658.183                 NaN           NaN
# ...

# %%
knn_imp = KNNImputer(n_neighbors=3)
knn_imp_ = knn_imp.fit_transform(econ_2018)

# %%
# Out:
# 4400.0

# %%
pd.DataFrame(knn_imp_, columns = econ_2018.columns, index = econ_2018.index)
# Out:
#                       Total Nonfarm  Mining and Logging  Construction  \
# State
# Alabama                    2046.258           10.000000     89.200000
# Alaska                      327.658           12.658000     15.833000
# Arizona                    2857.717           13.050000    157.400000
# Arkansas                   1267.492            5.933000     50.833000
# California                17172.225           22.492000    860.683000
# Colorado                   2726.925           28.525000    173.125000
# Connecticut                1699.275            0.567000     58.767000
# Delaware                    461.508            9.414000     24.994667
# District of Columbia        792.958           16.925000     45.483000
# Florida                    8780.950            5.742000    542.617000
# Georgia                    4535.942            9.533000    195.525000
# Hawaii                      658.183            8.594333     32.130667
# ...

# %%
it_imp = IterativeImputer(estimator = LinearRegression())
it_imp_econ_2018 = it_imp.fit_transform(econ_2018)

# %%
pd.DataFrame(it_imp_econ_2018, columns = econ_2018.columns, index = econ_2018.index)
# Out:
#                       Total Nonfarm  Mining and Logging  Construction  \
# State
# Alabama                    2046.258           10.000000     89.200000
# Alaska                      327.658           12.658000     15.833000
# Arizona                    2857.717           13.050000    157.400000
# Arkansas                   1267.492            5.933000     50.833000
# California                17172.225           22.492000    860.683000
# Colorado                   2726.925           28.525000    173.125000
# Connecticut                1699.275            0.567000     58.767000
# Delaware                    461.508         -132.579955    154.879955
# District of Columbia        792.958         -139.229955    154.879955
# Florida                    8780.950            5.742000    542.617000
# Georgia                    4535.942            9.533000    195.525000
# Hawaii                      658.183         -117.287955    154.879955
# ...

# %%
econ_2018[econ_2018.isna().any(axis=1)]
# Out:
#                       Total Nonfarm  Mining and Logging  Construction  \
# State
# Alabama                    2046.258              10.000        89.200
# Alaska                      327.658              12.658        15.833
# Arizona                    2857.717              13.050       157.400
# Arkansas                   1267.492               5.933        50.833
# California                17172.225              22.492       860.683
# Colorado                   2726.925              28.525       173.125
# Connecticut                1699.275               0.567        58.767
# Delaware                    461.508                 NaN           NaN
# District of Columbia        792.958                 NaN           NaN
# Florida                    8780.950               5.742       542.617
# Georgia                    4535.942               9.533       195.525
# Hawaii                      658.183                 NaN           NaN
# ...

# %%
pd.DataFrame(it_imp_econ_2018, columns = econ_2018.columns, index = econ_2018.index)
# Out:
#                       Total Nonfarm  Mining and Logging  Construction  \
# State
# Alabama                    2046.258           10.000000     89.200000
# Alaska                      327.658           12.658000     15.833000
# Arizona                    2857.717           13.050000    157.400000
# Arkansas                   1267.492            5.933000     50.833000
# California                17172.225           22.492000    860.683000
# Colorado                   2726.925           28.525000    173.125000
# Connecticut                1699.275            0.567000     58.767000
# Delaware                    461.508         -132.740956    154.879813
# District of Columbia        792.958         -139.360819    154.879824
# Florida                    8780.950            5.742000    542.617000
# Georgia                    4535.942            9.533000    195.525000
# Hawaii                      658.183         -117.429659    154.879838
# ...
